# %% [markdown]
# <a href="https://colab.research.google.com/github/Dimonfordont/DS_course/blob/main/Basics/Python/python_basics_while_for.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Задание 1: Подсчёт здоровья персонажа
#
#  Напишите программу, которая будет уменьшать здоровье персонажа на определённую величину с каждым ударом, пока его здоровье не станет равным или меньше 0.
#
#
# У персонажа есть начальное здоровье (например, 100).
# Каждый раз, когда персонаж получает удар, его здоровье уменьшается на случайное количество очков (например, от 5 до 15).
# Программа должна продолжать уменьшать здоровье до тех пор, пока оно не станет равным или меньше нуля.
# Программа должна выводить текущее здоровье персонажа после каждого удара.
#
# ** Для случайного значения используйте результат вызова функции get_damage

# %%
from random import randint

def get_damage():
  return randint(5,15)

# %%
# Инициализация начального здоровья персонажа
health =
print(f"Начальное здоровье персонажа: {health}")

# Цикл, который продолжается, пока здоровье больше 0
while health > 0:
    damage =  # Вызываем функцию урона
    health    # Изменяем здоровье

    # Вывод текущего здоровья после удара
    print(f"Получен урон: {damage}. Текущее здоровье: {health}")

    # Если здоровье стало меньше или равно 0, персонаж погиб
    if
        print("Персонаж погиб!")

# %% [markdown]
# ## Задача 2: Персонажи в партии (Проход по списку)
#
# У нас есть список персонажей в группе приключенцев. Нужно пройти по этому списку и вывести имена только тех, кто является людьми.
#
# Шаги:
#
# 1. Создайте список персонажей в вложенными словарями (сименами и расами).
# 2. Пройдитесь по списку с помощью цикла for.
# 3. Используйте условие для проверки, является ли персонаж человеком.
# 4. Выведите имена всех эльфов.

# %%
party = [
    {'name': 'Ciridan', 'race': 'Human'},
    {'name': 'Alex', 'race': 'Drow'
    {
    {
    {
]

# цикл for
  # if
        print(

# %% [markdown]
# # Задача 3: Бой с монстрами
#
# Герой сражается с монстрами в подземелье. Нужно пройти по списку монстров и остановить бой, как только герой встретит дракона - герою конец.
#
# Шаги:
#
# 1. Создайте список монстров.
# 2. Используйте цикл for, чтобы пройти по списку.
# 3. При встрече с драконом завершите цикл с помощью break.

# %%
monsters = ['Goblin',  'Orc', 'Dragon', 'Troll',

for # элемент в списке
    print(#пишем о победе
    if
          # пишем о великом бое
          # бой заночен

# %% [markdown]
# ##Задача 4: Проверка уровня персонажей
#
# У нас есть список персонажей с их уровнями. Нужно пройти по этому списку и вывести только тех, чьи уровни выше 5, пропуская тех, у кого уровень 5 и ниже.
#
# Шаги:
#
# 1. Создайте список персонажей с их уровнями.
# 2. Используйте цикл for, чтобы пройти по списку но при желании можно использовать while с каунтером проходя по списку и вызывая словари по индексу ```characters[counter]["level"]```.
# 3. Пропускайте персонажей с уровнем 5 и ниже с помощью continue.

# %%
characters = [
    {'name': 'Tess', 'level': 12


# шаг 2 и 3
    if
    else:
     print(character['name'], "is level",

# %% [markdown]
# ## Задача 5: Логирование здоровья персонажей (while)
#
# У нас есть персонаж, чье здоровье снижается на 5 каждый ход. Нужно использовать цикл while, чтобы отслеживать, когда его здоровье станет ниже или равно 0.
#
# Шаги:
#
# 1. Создайте переменную для здоровья персонажа.
# 2. Используйте цикл while для симуляции боев.
# 3. Каждый раз снижайте здоровье на 5.
# 3. Остановите цикл, когда здоровье будет равно или меньше 0.

# %%
health
while


# Конец
print("The character has been defeated.")

# %% [markdown]
# ## Задача 6: Магические предметы в сундуке (вложенный цикл)
#
# В сундуке лежат магические предметы. Нужно пройти по каждому сундуку, проверить, есть ли в нем магическое оружие и выдать его персонажам, если оно есть.
#
# Шаги:
#
# 1. Используйте цикл for для прохода по каждому сундуку.
# 2. Используйте вложенный цикл для проверки каждого предмета в сундуке. (```for``` под ```for```)
# 3. Если предмет — оружие, выведите его и перейдите к следующему сундуку.
# 4. Поскольку у нас два оружия - лук и меч - используем тернарный оператор ```if``` вместе с булевым условием ИЛИ ```or```

# %%
chests = [
    ['Potion', 'Shield', 'Sword'],
    ['Ring', 'Helmet'],
    ['Bow', 'Arrow', 'Potion'],]


for
    for
        if
            #print(f"Found a magical weapon: {item}!")
            # если остановить вложенный цикл, тот цикл что на уровень выше продолжит выполнение
